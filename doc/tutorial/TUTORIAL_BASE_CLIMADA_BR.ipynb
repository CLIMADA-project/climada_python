# %% [markdown]
# # Step 1. Defining Exposures
#
# Exposure describes the set of assets, people, livelihoods, infrastructures, etc. within an area of interest in terms of their geographic location, their value etc.; in brief - everything potentially exposed to hazards.
#
# Using LitPop Exposures:
# https://climada-python.readthedocs.io/en/stable/tutorial/climada_entity_LitPop.html

# %%
# %matplotlib inline
from climada.climadaBR import *

climadabr = ClimadaBR()

# For this cell to work we need the gpw-v4-population-count-rev11_2020_30_sec_tif foulder.
# You can find out more about it in the LitPop tutorial. After downloading, you can copy it to the system
#  directory or to your preferred repository.
# If you are using gpw-v4-population-count-rev11_2020_30_sec_tif (NASA) in the climada system directory 
# "SYSTEM_DIR" you don't need any aditional arguments, but if it is in another directory you can include 
# the path by adding the argument: Path("/path/to/your/directory/").
# For example: climadabr.DefineExposures(['BRA'], 300, 'income_group', Path("/content/Climada_Workspace/climada_python/climada/data/"))
climadabr.DefineExposures(['BRA'], 300, 'income_group')
# Out:
# 2024-08-14 13:48:15,395 - climada.entity.exposures.litpop.litpop - INFO -
#  LitPop: Init Exposure for country: BRA (76)...
#
# 2024-08-14 13:48:22,788 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:22,790 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:22,844 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:22,845 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:22,932 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:22,933 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:22,960 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:22,961 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:22,988 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:22,989 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:23,021 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:23,022 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:23,048 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:23,049 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:23,084 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:23,085 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:23,104 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:23,105 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:23,137 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:23,137 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:23,165 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:23,166 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:23,188 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:23,189 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:23,210 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:23,211 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:23,236 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:23,236 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:23,257 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:23,258 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:23,290 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:23,291 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:23,316 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:23,317 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:23,338 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:23,339 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:23,369 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:23,369 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:23,390 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:23,391 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:23,418 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:23,418 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:23,449 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:23,450 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:23,474 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:23,474 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:23,494 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:23,495 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:23,518 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:23,519 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:23,541 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:23,542 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:23,565 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:23,566 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:23,586 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:23,587 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:23,610 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:23,611 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:23,636 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:23,637 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:23,660 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:23,661 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:23,669 - climada.entity.exposures.litpop.litpop - INFO - No data point on destination grid within polygon.
# 2024-08-14 13:48:23,670 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:23,671 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:23,676 - climada.entity.exposures.litpop.litpop - INFO - No data point on destination grid within polygon.
# 2024-08-14 13:48:23,676 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:23,677 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:23,703 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:23,704 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:23,733 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:23,733 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:23,757 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:23,757 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:23,776 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:23,777 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:23,798 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:23,798 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:23,819 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:23,820 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:23,840 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:23,841 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:23,848 - climada.entity.exposures.litpop.litpop - INFO - No data point on destination grid within polygon.
# 2024-08-14 13:48:23,849 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:23,850 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:23,872 - climada.entity.exposures.litpop.gpw_population - WARNING - Reference year: 2018. Using nearest available year for GPW data: 2020
# 2024-08-14 13:48:23,872 - climada.entity.exposures.litpop.gpw_population - INFO - GPW Version v4.11
# 2024-08-14 13:48:24,268 - climada.util.finance - INFO - GDP BRA 2018: 1.917e+12.
# 2024-08-14 13:48:24,296 - climada.util.finance - INFO - Income group BRA 2018: 3.
# 2024-08-14 13:48:24,315 - climada.entity.exposures.base - INFO - Hazard type not set in impf_
# 2024-08-14 13:48:24,316 - climada.entity.exposures.base - INFO - category_id not set.
# 2024-08-14 13:48:24,317 - climada.entity.exposures.base - INFO - cover not set.
# 2024-08-14 13:48:24,318 - climada.entity.exposures.base - INFO - deductible not set.
# 2024-08-14 13:48:24,318 - climada.entity.exposures.base - INFO - centr_ not set.
# 2024-08-14 13:48:24,319 - climada.entity.exposures.base - INFO - Hazard type not set in impf_
# 2024-08-14 13:48:24,320 - climada.entity.exposures.base - INFO - category_id not set.
# 2024-08-14 13:48:24,320 - climada.entity.exposures.base - INFO - cover not set.
# 2024-08-14 13:48:24,321 - climada.entity.exposures.base - INFO - deductible not set.
# 2024-08-14 13:48:24,321 - climada.entity.exposures.base - INFO - centr_ not set.
# 2024-08-14 13:48:24,327 - climada.util.coordinates - INFO - Raster from resolution 0.08333332999999854 to 0.08333332999999854.

# %% [markdown]
# # Step 2. Defining Hazards
#
# A hazard describes climate-related events such as storms, floods, droughts, or heat waves both in terms of probability of occurrence as well as physical intensity.
#
# **IMPORTANT:** In our project, we will extend the hazards to include events generated by climate change, such as the growth of diseases, mosquito-borne vectors, impacts on crops, pollution, effects on the healthcare system, and any other range of events that we can model from news articles extracted from the portals of the country in question.

# %%
climadabr.DefineRandomHazards()

# %% [markdown]
# # Step 3. Computing Impact
#
# The impact is the combined effect of hazard events on a set of exposures mediated by a set of impact functions. By computing the impact for each event (historical and synthetic) and for each exposure value at each geographical location, the Impact provides different risk measures, such as the expected annual impact per exposure, the probable maximum impact for different return periods, and the total average annual impact.
#
# An impact function relates the percentage of damage in the exposure to the hazard intensity, also commonly referred to as a “vulnerability curve” in the modelling community. Every hazard and exposure types are characterized by an impact function.

# %%
climadabr.DefineRandomImpactFuncSet()
climadabr.ComputeImpact()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 climadabr.DefineRandomImpactFuncSet()
#       2 climadabr.ComputeImpact()
#
# File ~/Climada_IC/CLIMADA-BR/climada/climadaBR/climadaBR_def.py:146, in ClimadaBR.DefineRandomImpactFuncSet(self)
#     134 paa = np.concatenate((np.array([0]), np.sort(np.random.rand(14))), axis=0)
#     136 imp_fun = ImpactFunc(
#     137     id='WEBSENSORS',
#     138     name=name,
#    (...)
#     143     paa=paa,
#     144 )
# --> 146 self.AddImpactFunc(imp_fun)
#
# File ~/Climada_IC/CLIMADA-BR/climada/climadaBR/climadaBR_def.py:115, in ClimadaBR.AddImpactFunc(self, imp_fun)
#     112 imp_fun.plot()
#     114 # add the impact function to an Impact function set
# --> 115 self.impf_set.append(imp_fun)
#     116 self.impf_set.check()
#
# AttributeError: 'NoneType' object has no attribute 'append'
